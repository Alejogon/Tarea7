# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
n_x = 200
n_t = 1500

c = 1
dx = 1.0 / 100.0
dt = 1.0 / 5000.0

B = c*dt / dx

x = linspace(0, 2.0, n_x)

print B
# Out:
# 0.02

# %%
#Condiciones iniciales 
u = 3.0 * sin(pi*x)

# %%
t = zeros(n_t)
for i in range (n_t):
    t[i] = (i)*dt

# %%
plot (x,u)

# %%
#Condiciones de contorno fijas
u[0]= 0
u[-1] = 0

# %% [markdown]
# # Primer punto

# %%
u_past = zeros(n_x)
u_2past = zeros(n_x)

utodos=np.zeros((n_x,n_t))


for j in range (n_x):
    utodos[j,0]=u[j]


for n in range(n_t):  
    plot(x,u)
    u_past = u.copy() 
    u_2past = u_past.copy()
    for i in range(2,n_x-1):
        u[i]=u_2past[i]-(B/2)*( u_past[i+1]**2 -  u_past[i-1]**2 )
        utodos[i,j]=u[i]

# %%
plot (x,u)

# %%
#Grafica 3D

x = linspace(0,2,n_x)
t = linspace(0,2,n_t)

fig = plt.figure(figsize(15,10))
ax = fig.gca(projection='3d')
x ,t = np.meshgrid(x,t)
surf = ax.plot_wireframe(x,t,utodos)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# %% [markdown]
# # Segundo punto

# %%
u = 3.0 * sin(pi*x)
u_past = zeros(n_x)

for n in range(n_t):  
    plot(x,u)
    u_past = u.copy() 
    
    for i in range(1,n_x-1):
        u[i]= u_past[i]-(B/4.0)*(u_past[i+1]**2 - u_past[i-1]**2) + ((B**2)/8.0)*((u_past[i+1] + u_past[i])*(u_past[i+1]**2  -  u_past[i]**2) - ( u_past[i] + u_past[i-1])*( u_past[i]**2 - u_past[i-1]**2 ))

# %%
plot (x,u)
