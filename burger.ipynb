# %%
# %pylab inline
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n_x = 200
n_t = 1500

c = 1
dx = 1.0 / 100.0
dt = 1.0 / 5000.0

B = c*dt / dx

x = linspace(0, 2.0, n_x)

print B
# Out:
# 0.02

# %%
#Condiciones iniciales 
u = 3.0 * sin(pi*x)

# %%
t = zeros(n_t)
for i in range (n_t):
    t[i] = (i+1)*dt

# %%
plot (x,u)

# %%
#Condiciones de contorno fijas
u[0]= 0
u[-1] = 0

# %% [markdown]
# # Primer punto

# %%
u_past = zeros(n_x)
u_2past = zeros(n_x)
for n in range(n_t):  
    plot(x,u)
    u_past = u.copy() 
    u_2past = u_past.copy()
    for i in range(2,n_x-1):
        u[i]=u_2past[i]-(B/2)*( u_past[i+1]**2 -  u_past[i-1]**2 )

# %%
plot (x,u)

# %%
#Grafica 3D

grid_x, grid_y = mgrid[-1:1:200j, -1:1:200j]
grid_z = u

fig = figure()
ax = fig.add_subplot(1,1,1, projection='3d')
ax.plot_surface(grid_x,grid_y,grid_z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ff8bdbfaf074> in <module>()
#       6 fig = figure()
#       7 ax = fig.add_subplot(1,1,1, projection='3d')
# ----> 8 ax.plot_surface(grid_x,grid_y,grid_z)
#
# /System/Library/Frameworks/Python.framework/Versions/2.7/Extras/lib/python/mpl_toolkits/mplot3d/axes3d.pyc in plot_surface(self, X, Y, Z, *args, **kwargs)
#    1359         # If they can not be fitted to that shape,
#    1360         # then an exception is automatically thrown.
# -> 1361         X.shape = (rows, cols)
#    1362         Y.shape = (rows, cols)
#    1363
#
# ValueError: total size of new array must be unchanged

# %% [markdown]
# # Segundo punto

# %%
u = 3.0 * sin(pi*x)
u_past = zeros(n_x)

for n in range(n_t):  
    plot(x,u)
    u_past = u.copy() 
    
    for i in range(1,n_x-1):
        u[i]= u_past[i]-(B/4.0)*(u_past[i+1]**2 - u_past[i-1]**2) + ((B**2)/8.0)*((u_past[i+1] + u_past[i])*(u_past[i+1]**2  -  u_past[i]**2) - ( u_past[i] + u_past[i-1])*( u_past[i]**2 - u_past[i-1]**2 ))

# %%
plot (x,u)
