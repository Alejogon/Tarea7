# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n_x = 200
n_t = 200

c = 1
dx = 1.0 / 100.0
dt = 1.0 / 200.0

B = c*dt / dx

x = linspace(0, 2.0, n_x)

# %%
#Condiciones iniciales 
u = 3.0 * sin(pi*x)

# %%
plot (x,u)

# %%
#Condiciones de contorno fijas
u[0]= 0
u[-1] = 0

# %% [markdown]
# # Primer punto

# %%
u_past = zeros(n_x)

for n in range(n_t):  
    plot(x,u)
    u_past = u.copy() 
    
    for i in range(1,n_x-1):
        u[i]=u_past[i]-(0.01)*( u_past[i+1]**2 -  u_past[i-1]**2 )

# %%
plot (x,u)
print u
# Out:
# [ 0.          0.05382681  0.10764388  0.16144144  0.21520972  0.2689389
#   0.32261912  0.3762405   0.42979304  0.4832667   0.53665136  0.58993678
#   0.64311261  0.69616839  0.74909353  0.80187726  0.85450869  0.90697671
#   0.95927006  1.01137725  1.06328658  1.1149861   1.16646362  1.21770666
#   1.26870246  1.31943795  1.3698997   1.42007396  1.46994657  1.51950299
#   1.56872822  1.61760683  1.66612287  1.71425989  1.76200086  1.80932817
#   1.85622359  1.90266818  1.9486423   1.99412553  2.03909664  2.0835335
#   2.12741305  2.17071121  2.21340283  2.25546159  2.29685994  2.33756897
#   2.37755835  2.41679617  2.45524888  2.49288111  2.52965553  2.5655327
#   2.60047089  2.63442589  2.66735075  2.6991956   2.72990734  2.75942934
#   2.7877011   2.81465791  2.84023036  2.86434391  2.88691832  2.90786705
#   2.92709653  2.94450537  2.95998346  2.97341084  2.98465653  2.9935771
#   3.00001494  3.0037964   3.00472938  3.00260072  2.99717285  2.98817999
# ...
