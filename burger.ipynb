# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
n_x = 200
n_t = 200

c = 1
dx = 1.0 / 100.0
dt = 1.0 / 200.0

B = c*dt / dx

x = linspace(0, 2.0, n_x)

# %%
#Condiciones iniciales 
u = 3.0 * sin(pi*x)

# %%
plot (x,u)

# %%
#Condiciones de contorno fijas
u[0]= 0
u[-1] = 0

# %% [markdown]
# # Primer punto

# %%
u_past = zeros(n_x)

for n in range(n_t):  
    plot(x,u)
    u_past = u.copy() 
    
    for i in range(1,n_x-1):
        u[i]=u_past[i]-(B*0.5)*( u_past[i+1] -  u_past[i-1] )

# %%
plot (x,u)
print u
# Out:
# [  0.00000000e+00   4.39467188e+05  -4.25952813e+04  -1.29591845e+06
#   -2.03566518e+04   2.07658852e+06   2.74681711e+05  -2.70697580e+06
#   -7.65362249e+05   3.08949521e+06   1.47540809e+06  -3.11812124e+06
#   -2.31070430e+06   2.71096123e+06   3.10102555e+06  -1.85481051e+06
#   -3.62797744e+06   6.46243346e+05   3.68425516e+06   6.93768672e+05
#   -3.15422977e+06  -1.85377703e+06   2.08746926e+06   2.52112090e+06
#   -7.24607953e+05  -2.50436747e+06  -5.57860472e+05   1.83596610e+06
#    1.38367234e+06  -7.91199693e+05  -1.54319226e+06  -2.12228255e+05
#    1.10201618e+06   8.04085419e+05  -3.74561262e+05  -8.43009663e+05
#   -2.43085167e+05   4.74774149e+05   4.90123506e+05  -1.93815414e+04
#   -3.67576070e+05  -2.42557400e+05   8.72914769e+04   2.33101055e+05
#    1.12181242e+05  -7.49643022e+04  -1.33612092e+05  -5.43092315e+04
#    4.53584210e+04   7.23875157e+04   3.01868573e+04  -2.12322108e+04
#   -3.72684129e+04  -1.88625918e+04   6.64984115e+03   1.75579683e+04
# ...
